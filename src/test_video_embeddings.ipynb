# %%
# Video Pipeline Test: Video → Frame Sampling → Temporal Embeddings

# Test the complete video pipeline:
# 1. Load videos with CelebDFVisualDataset
# 2. Extract 8 uniformly-sampled frames with face detection (224x224)
# 3. Generate temporal embeddings with VisualEncoder (Xception + LSTM + Attention)
# 4. Validate output shapes and dimensions

# %%
# Step 1: Setup and imports
import sys
import torch
from torch.utils.data import DataLoader, Subset
from pathlib import Path

# Add src to path
src_path = Path(r"D:\florida_coursework\third_sem\multimedia_expert_systems\multimedia_prototype\mutlimedia_mvp\src")
sys.path.insert(0, str(src_path))

from loaders.visual_loader import CelebDFVisualDataset
from encoders.visual_encoder import VisualEncoder

# Check device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Data path
data_root = Path(r"D:\florida_coursework\third_sem\multimedia_expert_systems\multimedia_prototype\data\celeb_df")
print(f"Data directory: {data_root}")
print(f"Exists: {data_root.exists()}")
# Out:
# Using device: cuda
# Data directory: D:\florida_coursework\third_sem\multimedia_expert_systems\multimedia_prototype\data\celeb_df
# Exists: True

# %%
# Step 2: Load full dataset and create small test subset
print("Loading video dataset...")
frames_per_video = 8  # Number of frames to extract per video

dataset = CelebDFVisualDataset(
    root_dir=data_root,
    frames_per_video=frames_per_video
)


# Create small test subset (5 videos - face detection is slow)
# test_indices = list(range(5))
# dataset = Subset(dataset, test_indices)

# print(f"\n✓ Created test subset: {len(dataset)} videos")


print(f"✓ Total videos in dataset: {len(dataset)}")
print(f"  Sample video paths: {dataset.video_paths[:3]}")
print(f"  Sample labels: {dataset.labels[:3]} (0=real, 1=fake)")
print(f"  Frames per video: {frames_per_video}")
# Out:
# Loading video dataset...
# ✓ Total videos in dataset: 6529
#   Sample video paths: ['D:\\florida_coursework\\third_sem\\multimedia_expert_systems\\multimedia_prototype\\data\\celeb_df\\Celeb-real\\id0_0000.mp4', 'D:\\florida_coursework\\third_sem\\multimedia_expert_systems\\multimedia_prototype\\data\\celeb_df\\Celeb-real\\id0_0001.mp4', 'D:\\florida_coursework\\third_sem\\multimedia_expert_systems\\multimedia_prototype\\data\\celeb_df\\Celeb-real\\id0_0002.mp4']
#   Sample labels: [0, 0, 0] (0=real, 1=fake)
#   Frames per video: 8

# %%
# Step 3: Test single sample - frame extraction and preprocessing
print("Testing single sample frame extraction...")
print("⏳ This may take 10-30 seconds (face detection on 8 frames)...\n")

sample_frames, sample_label = dataset[0]

print(f"✓ Extracted video frames: {sample_frames.shape}")
print(f"  Expected shape: ({frames_per_video}, 3, 224, 224) - 8 RGB frames")
print(f"  Data range: [{sample_frames.min():.3f}, {sample_frames.max():.3f}]")
print(f"  Label: {sample_label.item()} ({'real' if sample_label.item() == 0 else 'fake'})")

# Check if faces were detected (non-zero tensors)
non_zero_frames = (sample_frames.sum(dim=(1,2,3)) > 0).sum().item()
print(f"  Frames with detected faces: {non_zero_frames}/{frames_per_video}")

if non_zero_frames == 0:
    print("⚠ Warning: No faces detected in this video (all zeros)")
elif non_zero_frames < frames_per_video:
    print(f"⚠ Warning: Only {non_zero_frames} frames had detected faces (padded with zeros)")
else:
    print("✓ All frames successfully extracted with faces!")
# Out:
# Testing single sample frame extraction...
# ⏳ This may take 10-30 seconds (face detection on 8 frames)...
#
# ✓ Extracted video frames: torch.Size([8, 3, 224, 224])
#   Expected shape: (8, 3, 224, 224) - 8 RGB frames
#   Data range: [0.000, 0.937]
#   Label: 0 (real)
#   Frames with detected faces: 8/8
# ✓ All frames successfully extracted with faces!

# %%
# Step 4: Create DataLoader for batch processing
print("Creating DataLoader...")
test_loader = DataLoader(
    dataset,
    batch_size=2,  # Small batch due to video memory requirements
    shuffle=False,
    num_workers=0  # Use 0 for Windows to avoid multiprocessing issues
)

print(f"✓ Created DataLoader with {len(test_loader)} batches")

# Test one batch (this will take time due to face detection)
print("\n⏳ Loading one batch (may take 20-60 seconds)...")
batch_frames, batch_labels = next(iter(test_loader))

print(f"\nBatch content:")
print(f"  - Frames: {batch_frames.shape}")
print(f"  - Labels: {batch_labels.shape}, values: {batch_labels.tolist()}")
print(f"  - Memory usage: ~{batch_frames.element_size() * batch_frames.nelement() / 1024**2:.2f} MB")
# Out:
# Creating DataLoader...
# ✓ Created DataLoader with 3265 batches
#
# ⏳ Loading one batch (may take 20-60 seconds)...
#
# Batch content:
#   - Frames: torch.Size([2, 8, 3, 224, 224])
#   - Labels: torch.Size([2]), values: [0, 0]
#   - Memory usage: ~9.19 MB

# %%
# Step 5: Initialize VisualEncoder
print("Loading VisualEncoder (Xception + LSTM + Attention)...")

# Configure to match audio/image encoders
lstm_hidden = 256  # LSTM hidden size
embed_dim = lstm_hidden * 2  # 512 (bidirectional LSTM output)

encoder = VisualEncoder(
    backbone_name="xception",
    pretrained=True,
    lstm_hidden=lstm_hidden,
    lstm_layers=1,
    bidirectional=True,
    dropout=0.3,
    frame_chunk_size=32
).to(device)

encoder.eval()  # Set to evaluation mode

print(f"✓ VisualEncoder loaded on {device}")
print(f"  Backbone: Xception (pretrained on ImageNet)")
print(f"  Frame feature dim: {encoder.frame_feat_dim}")
print(f"  LSTM hidden: {lstm_hidden} (bidirectional)")
print(f"  Output dimension: {encoder.get_out_dim()}")
print(f"  Total parameters: {sum(p.numel() for p in encoder.parameters()):,}")
# Out:
# Loading VisualEncoder (Xception + LSTM + Attention)...
# C:\Users\muthu\miniconda3\envs\multi_env\Lib\site-packages\timm\models\_factory.py:138: UserWarning: Mapping deprecated model name xception to current legacy_xception.
#   model = create_fn(
# ✓ VisualEncoder loaded on cuda
#   Backbone: Xception (pretrained on ImageNet)
#   Frame feature dim: 2048
#   LSTM hidden: 256 (bidirectional)
#   Output dimension: 512
#   Total parameters: 25,661,225

# %%
# Step 6: Generate temporal embeddings for all test batches
print("Generating video embeddings...")
print("⏳ This will take a few minutes (frame extraction + encoding)...\n")

all_embeddings = []
all_labels = []

with torch.no_grad():
    for i, (frames, labels) in enumerate(test_loader):
        print(f"  Processing batch {i+1}/{len(test_loader)}...")
        
        # Move batch to device
        frames = frames.to(device)  # (B, T, C, H, W)
        
        # Generate temporal embeddings
        embeddings = encoder(frames)
        
        # Store results
        all_embeddings.append(embeddings.cpu())
        all_labels.append(labels)
        
        print(f"    Input: {frames.shape} → Embeddings: {embeddings.shape}")

# Concatenate all batches
all_embeddings = torch.cat(all_embeddings, dim=0)
all_labels = torch.cat(all_labels, dim=0)

print(f"\n✓ Final Results:")
print(f"  Total embeddings: {all_embeddings.shape}")
print(f"  Total labels: {all_labels.shape}")
print(f"  Labels distribution: real={(all_labels==0).sum().item()}, fake={(all_labels==1).sum().item()}")
print(f"\n🎉 Video embeddings ready for multimodal fusion!")
# Out:
# Generating video embeddings...
# ⏳ This will take a few minutes (frame extraction + encoding)...
#
#   Processing batch 1/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch
3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 363/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 364/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 365/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 366/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 367/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 368/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 369/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 370/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 371/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 372/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 373/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 374/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 375/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 376/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 377/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 378/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 379/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 380/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 381/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 382/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 383/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 384/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 385/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 386/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 387/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 388/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 389/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 390/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 391/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 392/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 393/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 394/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 395/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 396/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 397/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 398/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 399/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 400/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 401/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 402/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 403/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 404/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 405/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 406/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 407/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 408/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 409/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 410/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 411/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 412/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 413/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 414/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 415/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 416/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 417/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 418/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 419/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 420/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 421/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 422/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 423/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 424/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 425/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 426/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 427/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 428/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 429/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 430/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 431/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 432/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 433/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 434/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 435/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 436/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 437/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 438/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 439/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 440/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 441/3265...
# ...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3123/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3124/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3125/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3126/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3127/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3128/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3129/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3130/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3131/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3132/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3133/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3134/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3135/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3136/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3137/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3138/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3139/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3140/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3141/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3142/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3143/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3144/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3145/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3146/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3147/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3148/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3149/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3150/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3151/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3152/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3153/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3154/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3155/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3156/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3157/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3158/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3159/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3160/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3161/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3162/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3163/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3164/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3165/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3166/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3167/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3168/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3169/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3170/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3171/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3172/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3173/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3174/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3175/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3176/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3177/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3178/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3179/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3180/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3181/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3182/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3183/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3184/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3185/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3186/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3187/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3188/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3189/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3190/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3191/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3192/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3193/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3194/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3195/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3196/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3197/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3198/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3199/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3200/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3201/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3202/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3203/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3204/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3205/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3206/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3207/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3208/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3209/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3210/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3211/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3212/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3213/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3214/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3215/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3216/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3217/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3218/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3219/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3220/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3221/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3222/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3223/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3224/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3225/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3226/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3227/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3228/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3229/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3230/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3231/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3232/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3233/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3234/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3235/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3236/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3237/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3238/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3239/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3240/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3241/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3242/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3243/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3244/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3245/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3246/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3247/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3248/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3249/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3250/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3251/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3252/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3253/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3254/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3255/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3256/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3257/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3258/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3259/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3260/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3261/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3262/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3263/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3264/3265...
#     Input: torch.Size([2, 8, 3, 224, 224]) → Embeddings: torch.Size([2, 512])
#   Processing batch 3265/3265...
#     Input: torch.Size([1, 8, 3, 224, 224]) → Embeddings: torch.Size([1, 512])
#
# ✓ Final Results:
#   Total embeddings: torch.Size([6529, 512])
#   Total labels: torch.Size([6529])
#   Labels distribution: real=890, fake=5639
#
# 🎉 Video embeddings ready for multimodal fusion!

# %%
save_path = "embeddings/video_embeddings.pt"
torch.save({
    "embeddings": all_embeddings,   # (N, D)
    "labels": all_labels            # (N,)
}, save_path)

print("Saved:", save_path)
# Out:
# Saved: embeddings/video_embeddings.pt

# %%
data = torch.load("embeddings/video_embeddings.pt")
video_embeddings = data["embeddings"]    # torch.Tensor
video_labels = data["labels"]            # torch.Tensor
video_embeddings, video_labels
# Out:
# (tensor([[-0.0239,  0.0959, -0.0075,  ..., -0.1034,  0.1031,  0.1394],
#          [ 0.0005,  0.1355, -0.0237,  ..., -0.1124, -0.0067,  0.0664],
#          [ 0.0802,  0.1241, -0.0864,  ...,  0.0914,  0.0502,  0.0687],
#          ...,
#          [ 0.0071,  0.0323,  0.0616,  ...,  0.0188,  0.0628,  0.1270],
#          [-0.0028,  0.2159,  0.1033,  ...,  0.0776, -0.0029,  0.1234],
#          [-0.0195,  0.1740,  0.0761,  ..., -0.0966,  0.0230,  0.0768]]),
#  tensor([0, 0, 0,  ..., 1, 1, 1]))
